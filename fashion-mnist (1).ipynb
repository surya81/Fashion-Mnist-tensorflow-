# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Dataset
# **WE will load data from keras API it is a fashion dataset containing images of different fashion accessories**

# %%
fashion_mnist = keras.datasets.fashion_mnist

# %%
(x_train_full,y_train_full),(X_test,y_test) = fashion_mnist.load_data()

# %%
x_train_full.shape

# %% [markdown]
# # Validation Datasets

# %%
x_valid,x_train =x_train_full[:5000]/255.0,x_train_full[5000:]/255.0
y_valid,y_train =y_train_full[:5000],y_train_full[5000:]

# %%
class_names =["T-shirt/top","Trouser","Pullover","Dress","Coat","Sandal","shirt","Sneaker","bag","ankle boot"]

# %%
class_names[y_train[0]]

# %%
plt.imshow(x_valid[0], cmap="binary")
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.heatmap(x_valid[0], annot=True, cmap="binary")

# %% [markdown]
# # Model
# **we will create a sequence of model using sequenctial function also we will use softmax as outer layer function **

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28,28]))
model.add(keras.layers.Dense(300,activation ="relu"))
model.add(keras.layers.Dense(100,activation = "relu"))
model.add(keras.layers.Dense(10,activation ="softmax"))

# %% [markdown]
# # Model Summary

# %%
model.summary()

# %%
model.layers

# %%
model.layers[1].name

# %% [markdown]
# # Random Initialized weights

# %%
hidden1 = model.layers[1]
hidden1.name

# %%
weights, biases = hidden1.get_weights()

# %%
print(weights.shape)
weights

# %%
model.compile(loss ="sparse_categorical_crossentropy",optimizer="sgd",metrics=["accuracy"])

# %%
History = model.fit(x_train,y_train,epochs=30,validation_data =(x_valid,y_valid))

# %%
pd.DataFrame(History.history)

# %% [markdown]
# # Visualization of Result

# %%
import pandas as pd
pd.DataFrame(History.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()

# %%
model.evaluate(X_test,y_test)

# %%
x_new = X_test[:5]
y_prob = model.predict(x_new)
y_prob.round(2)

# %%
y_pred = np.argmax(model.predict(x_new), axis=1)
y_pred

# %%
y_test_new = y_test[:5]
for data, pred, actual in zip(x_new, y_pred, y_test_new):
    plt.imshow(data, cmap="binary")
    plt.title(f"Predicted: {pred}, Actual: {actual}")
    plt.axis('off')
    plt.show()
    print("---"*20)
